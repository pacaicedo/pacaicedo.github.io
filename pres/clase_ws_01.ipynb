# %%
3*4
# Out:
# 12

# %%
"HOLA"*3
# Out:
# 'HOLAHOLAHOLA'

# %%
"a"*"b"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 "a"*"b"
#
# TypeError: can't multiply sequence by non-int of type 'str'
